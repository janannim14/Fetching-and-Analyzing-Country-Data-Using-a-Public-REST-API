# %%
import requests
import pandas as pd

api_url = "https://restcountries.com/v3.1/all?fields=name,population,region,area"

try:
    response = requests.get(api_url, timeout=15)

    print(f"HTTP Status Code: {response.status_code}")

    if response.status_code == 200:
        data = response.json()
        print(f"Success! Total number of countries retrieved: {len(data)}")
    else:
        print(f"Failed to fetch data. Status code: {response.status_code}")
        data = []

except Exception as e:
    print(f"An error occurred: {e}")
    data = []
# Out:
# HTTP Status Code: 200
# Success! Total number of countries retrieved: 250

# %%
countries_list = []

if data:
    for country in data:
        extracted_info = {
            "common_name": country.get("name", {}).get("common"),
            "population": country.get("population"),
            "region": country.get("region"),
            "area": country.get("area")
        }
        countries_list.append(extracted_info)

df = pd.DataFrame(countries_list)

print("First 10 rows of the DataFrame:")
display(df.head(10))
# Out:
# First 10 rows of the DataFrame:
#           common_name  population    region       area
# 0        Cook Islands       15040   Oceania      236.0
# 1              Guinea    14363931    Africa   245857.0
# 2    Christmas Island        1692   Oceania      135.0
# 3                Togo     8095498    Africa    56785.0
# 4              Taiwan    23317031      Asia    36197.0
# 5          Kyrgyzstan     7281800      Asia   199951.0
# 6            Suriname      616500  Americas   163820.0
# 7  Dominican Republic    10771504  Americas    48671.0
# 8           Guatemala    18079810  Americas   108889.0
# 9             Algeria    47400000    Africa  2381741.0

# %%
if not df.empty:
    region_population = df.groupby('region')['population'].sum()
    highest_pop_region = region_population.idxmax()
    highest_pop_value = region_population.max()

    largest_country = df.loc[df['area'].idxmax()]

    print(f"--- Summary Report ---")
    print(f"1. Region with the highest total population: {highest_pop_region} ({highest_pop_value:,})")
    print(f"2. Country with the largest area: {largest_country['common_name']} ({largest_country['area']:,} sq km)")
else:
    print("DataFrame is empty. Please run Task 1 and Task 2 successfully first.")
# Out:
# --- Summary Report ---
# 1. Region with the highest total population: Asia (4,724,731,966)
# 2. Country with the largest area: Russia (17,098,246.0 sq km)
